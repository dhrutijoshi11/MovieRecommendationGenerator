# %%
import pandas as pd

# Load the CSV file
data = pd.read_csv('data.csv')

# %%
pip install vaderSentiment
# Out:
# Requirement already satisfied: vaderSentiment in /usr/local/lib/python3.10/dist-packages (3.3.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from vaderSentiment) (2.27.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->vaderSentiment) (3.4)

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.12.0)

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd

# Here, 'reviews' is the column containing user reviews in your dataset
reviews = data['User Reviews']

# Initialize the sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Define threshold values for each emotion
thresholds = {
    'Fabulous': 0.3,
    'disappointed': -0.3,
    'anger': -0.3,
    'surprise': 0.1,
    'fear': -0.1,
    'disgust': -0.1
}

# Function to classify emotions based on sentiment scores
def classify_emotion(sentiment_score):
    for emotion, threshold in thresholds.items():
        if sentiment_score >= threshold:
            return emotion
    return 'Satisfy'  # If sentiment score does not fall into any threshold, consider it as 'Neutral'

# List to store the predicted emotions for each review
predicted_emotions = []

# Perform sentiment analysis on each review and classify emotions
for review in reviews:
    sentiment_score = analyzer.polarity_scores(review)['compound']
    emotion = classify_emotion(sentiment_score)
    predicted_emotions.append(emotion)

# Add the predicted emotions to the DataFrame
data['Emotion_imdb'] = predicted_emotions

# Display the DataFrame with the predicted emotions
print(data)
# Out:
#        Unnamed: 0.1  Unnamed: 0                 Title  Year  Rating  \
# 0                10          10          The Departed  2006     8.5
# 1                12          12          The Departed  2006     8.5
# 2                14          14          The Departed  2006     8.5
# 3                15          15          The Departed  2006     8.5
# 4                16          16          The Departed  2006     8.5
# ...             ...         ...                   ...   ...     ...
# 64561         81047       81047  The Power of the Dog  2021     6.8
# 64562         81048       81048  The Power of the Dog  2021     6.8
# 64563         81050       81050  The Power of the Dog  2021     6.8
# 64564         81051       81051  The Power of the Dog  2021     6.8
# 64565         81052       81052  The Power of the Dog  2021     6.8
#
#                        Genres  \
# 0      Crime, Drama, Thriller
# 1      Crime, Drama, Thriller
# 2      Crime, Drama, Thriller
# 3      Crime, Drama, Thriller
# 4      Crime, Drama, Thriller
# ...                       ...
# 64561          Drama, Western
# 64562          Drama, Western
# 64563          Drama, Western
# 64564          Drama, Western
# 64565          Drama, Western
#
#                                             User Reviews  \
# 0      When The Departed finally gained for Martin Sc...
# 1      When The Departed finally gained for Martin Sc...
# 2      When The Departed finally gained for Martin Sc...
# 3      When The Departed finally gained for Martin Sc...
# 4      When The Departed finally gained for Martin Sc...
# ...                                                  ...
# 64561  The Power of the Dog is Jane Campion's first f...
# 64562  The Power of the Dog is Jane Campion's first f...
# 64563  The Power of the Dog is Jane Campion's first f...
# 64564  The Power of the Dog is Jane Campion's first f...
# 64565  The Power of the Dog is Jane Campion's first f...
#
#                        Name  \
# 0              The Departed
# 1              The Departed
# 2              The Departed
# 3              The Departed
# 4              The Departed
# ...                     ...
# 64561  The Power of the Dog
# 64562  The Power of the Dog
# 64563  The Power of the Dog
# 64564  The Power of the Dog
# 64565  The Power of the Dog
#
#                                                RT_review sentiment_imdb  \
# 0      Martin Scorsese’s adaptation of the Hong Kong ...       Positive
# 1      If you like Scorsese, or if you just like thri...       Positive
# 2      Not only is The Departed not among the best of...       Positive
# 3      Nicholson is on good-to-great form as the pate...       Positive
# 4      One of the best crime dramas ever made, The De...       Positive
# ...                                                  ...            ...
# 64561  It's a slow build, and for most of the time, I...       Negative
# 64562  Campion handles such psychological denseness w...       Negative
# 64563  The Power of the Dog is a thought-provoking, d...       Negative
# 64564  When The Power of the Dog ends, there is an im...       Negative
# 64565  ‘The Power of the Dog’ is emotional and comple...       Negative
#
#       sentiment_rt Emotion_imdb
# 0         Positive     Fabulous
# 1         Positive     Fabulous
# 2         Negative     Fabulous
# 3         Positive     Fabulous
# 4         Positive     Fabulous
# ...            ...          ...
# 64561     Positive      Satisfy
# 64562     Positive      Satisfy
# 64563     Positive      Satisfy
# 64564     Positive      Satisfy
# 64565     Negative      Satisfy
#
# [64566 rows x 12 columns]

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd

# Here, 'reviews' is the column containing user reviews in your dataset
reviews = data['RT_review']

# Initialize the sentiment analyzer
analyzer = SentimentIntensityAnalyzer()

# Define threshold values for each emotion
thresholds = {
    'Fabulous': 0.3,
    'disappointed': -0.3,
    'anger': -0.3,
    'surprise': 0.1,
    'fear': -0.1,
    'disgust': -0.1
}

# Function to classify emotions based on sentiment scores
def classify_emotion(sentiment_score):
    for emotion, threshold in thresholds.items():
        if sentiment_score >= threshold:
            return emotion
    return 'Satisfy'  # If sentiment score does not fall into any threshold, consider it as 'Neutral'

# List to store the predicted emotions for each review
predicted_emotions = []

# Perform sentiment analysis on each review and classify emotions
for review in reviews:
    sentiment_score = analyzer.polarity_scores(review)['compound']
    emotion = classify_emotion(sentiment_score)
    predicted_emotions.append(emotion)

# Add the predicted emotions to the DataFrame
data['Emotion_RT'] = predicted_emotions

# Display the DataFrame with the predicted emotions
print(data)
# Out:
#        Unnamed: 0.1  Unnamed: 0                 Title  Year  Rating  \
# 0                10          10          The Departed  2006     8.5
# 1                12          12          The Departed  2006     8.5
# 2                14          14          The Departed  2006     8.5
# 3                15          15          The Departed  2006     8.5
# 4                16          16          The Departed  2006     8.5
# ...             ...         ...                   ...   ...     ...
# 64561         81047       81047  The Power of the Dog  2021     6.8
# 64562         81048       81048  The Power of the Dog  2021     6.8
# 64563         81050       81050  The Power of the Dog  2021     6.8
# 64564         81051       81051  The Power of the Dog  2021     6.8
# 64565         81052       81052  The Power of the Dog  2021     6.8
#
#                        Genres  \
# 0      Crime, Drama, Thriller
# 1      Crime, Drama, Thriller
# 2      Crime, Drama, Thriller
# 3      Crime, Drama, Thriller
# 4      Crime, Drama, Thriller
# ...                       ...
# 64561          Drama, Western
# 64562          Drama, Western
# 64563          Drama, Western
# 64564          Drama, Western
# 64565          Drama, Western
#
#                                             User Reviews  \
# 0      When The Departed finally gained for Martin Sc...
# 1      When The Departed finally gained for Martin Sc...
# 2      When The Departed finally gained for Martin Sc...
# 3      When The Departed finally gained for Martin Sc...
# 4      When The Departed finally gained for Martin Sc...
# ...                                                  ...
# 64561  The Power of the Dog is Jane Campion's first f...
# 64562  The Power of the Dog is Jane Campion's first f...
# 64563  The Power of the Dog is Jane Campion's first f...
# 64564  The Power of the Dog is Jane Campion's first f...
# 64565  The Power of the Dog is Jane Campion's first f...
#
#                        Name  \
# 0              The Departed
# 1              The Departed
# 2              The Departed
# 3              The Departed
# 4              The Departed
# ...                     ...
# 64561  The Power of the Dog
# 64562  The Power of the Dog
# 64563  The Power of the Dog
# 64564  The Power of the Dog
# 64565  The Power of the Dog
#
#                                                RT_review sentiment_imdb  \
# 0      Martin Scorsese’s adaptation of the Hong Kong ...       Positive
# 1      If you like Scorsese, or if you just like thri...       Positive
# 2      Not only is The Departed not among the best of...       Positive
# 3      Nicholson is on good-to-great form as the pate...       Positive
# 4      One of the best crime dramas ever made, The De...       Positive
# ...                                                  ...            ...
# 64561  It's a slow build, and for most of the time, I...       Negative
# 64562  Campion handles such psychological denseness w...       Negative
# 64563  The Power of the Dog is a thought-provoking, d...       Negative
# 64564  When The Power of the Dog ends, there is an im...       Negative
# 64565  ‘The Power of the Dog’ is emotional and comple...       Negative
#
#       sentiment_rt Emotion_imdb    Emotion_RT
# 0         Positive     Fabulous  disappointed
# 1         Positive     Fabulous      Fabulous
# 2         Negative     Fabulous       Satisfy
# 3         Positive     Fabulous  disappointed
# 4         Positive     Fabulous      Fabulous
# ...            ...          ...           ...
# 64561     Positive      Satisfy      Fabulous
# 64562     Positive      Satisfy      Fabulous
# 64563     Positive      Satisfy      Fabulous
# 64564     Positive      Satisfy      Fabulous
# 64565     Negative      Satisfy       Satisfy
#
# [64566 rows x 13 columns]

# %%
data
# Out:
#        Unnamed: 0.1  Unnamed: 0                 Title  Year  Rating  \
# 0                10          10          The Departed  2006     8.5
# 1                12          12          The Departed  2006     8.5
# 2                14          14          The Departed  2006     8.5
# 3                15          15          The Departed  2006     8.5
# 4                16          16          The Departed  2006     8.5
# ...             ...         ...                   ...   ...     ...
# 64561         81047       81047  The Power of the Dog  2021     6.8
# 64562         81048       81048  The Power of the Dog  2021     6.8
# 64563         81050       81050  The Power of the Dog  2021     6.8
# 64564         81051       81051  The Power of the Dog  2021     6.8
# 64565         81052       81052  The Power of the Dog  2021     6.8
#
#                        Genres  \
# 0      Crime, Drama, Thriller
# 1      Crime, Drama, Thriller
# 2      Crime, Drama, Thriller
# 3      Crime, Drama, Thriller
# 4      Crime, Drama, Thriller
# ...                       ...
# 64561          Drama, Western
# 64562          Drama, Western
# 64563          Drama, Western
# 64564          Drama, Western
# 64565          Drama, Western
#
#                                             User Reviews  \
# 0      When The Departed finally gained for Martin Sc...
# 1      When The Departed finally gained for Martin Sc...
# 2      When The Departed finally gained for Martin Sc...
# 3      When The Departed finally gained for Martin Sc...
# 4      When The Departed finally gained for Martin Sc...
# ...                                                  ...
# 64561  The Power of the Dog is Jane Campion's first f...
# 64562  The Power of the Dog is Jane Campion's first f...
# 64563  The Power of the Dog is Jane Campion's first f...
# 64564  The Power of the Dog is Jane Campion's first f...
# 64565  The Power of the Dog is Jane Campion's first f...
#
#                        Name  \
# 0              The Departed
# 1              The Departed
# 2              The Departed
# 3              The Departed
# 4              The Departed
# ...                     ...
# 64561  The Power of the Dog
# 64562  The Power of the Dog
# 64563  The Power of the Dog
# 64564  The Power of the Dog
# 64565  The Power of the Dog
#
#                                                RT_review sentiment_imdb  \
# 0      Martin Scorsese’s adaptation of the Hong Kong ...       Positive
# 1      If you like Scorsese, or if you just like thri...       Positive
# 2      Not only is The Departed not among the best of...       Positive
# 3      Nicholson is on good-to-great form as the pate...       Positive
# 4      One of the best crime dramas ever made, The De...       Positive
# ...                                                  ...            ...
# 64561  It's a slow build, and for most of the time, I...       Negative
# 64562  Campion handles such psychological denseness w...       Negative
# 64563  The Power of the Dog is a thought-provoking, d...       Negative
# 64564  When The Power of the Dog ends, there is an im...       Negative
# 64565  ‘The Power of the Dog’ is emotional and comple...       Negative
#
#       sentiment_rt Emotion_imdb    Emotion_RT
# 0         Positive     Fabulous  disappointed
# 1         Positive     Fabulous      Fabulous
# 2         Negative     Fabulous       Satisfy
# 3         Positive     Fabulous  disappointed
# 4         Positive     Fabulous      Fabulous
# ...            ...          ...           ...
# 64561     Positive      Satisfy      Fabulous
# 64562     Positive      Satisfy      Fabulous
# 64563     Positive      Satisfy      Fabulous
# 64564     Positive      Satisfy      Fabulous
# 64565     Negative      Satisfy       Satisfy
#
# [64566 rows x 13 columns]

# %%
#Drop Columns which is irrelevant
data.drop(columns='Unnamed: 0', inplace=True)
data.drop(columns='Name', inplace=True)
data.drop(columns='Unnamed: 0.1', inplace=True)

# %%
data
# Out:
#                       Title  Year  Rating                  Genres  \
# 0              The Departed  2006     8.5  Crime, Drama, Thriller
# 1              The Departed  2006     8.5  Crime, Drama, Thriller
# 2              The Departed  2006     8.5  Crime, Drama, Thriller
# 3              The Departed  2006     8.5  Crime, Drama, Thriller
# 4              The Departed  2006     8.5  Crime, Drama, Thriller
# ...                     ...   ...     ...                     ...
# 64561  The Power of the Dog  2021     6.8          Drama, Western
# 64562  The Power of the Dog  2021     6.8          Drama, Western
# 64563  The Power of the Dog  2021     6.8          Drama, Western
# 64564  The Power of the Dog  2021     6.8          Drama, Western
# 64565  The Power of the Dog  2021     6.8          Drama, Western
#
#                                             User Reviews  \
# 0      When The Departed finally gained for Martin Sc...
# 1      When The Departed finally gained for Martin Sc...
# 2      When The Departed finally gained for Martin Sc...
# 3      When The Departed finally gained for Martin Sc...
# 4      When The Departed finally gained for Martin Sc...
# ...                                                  ...
# 64561  The Power of the Dog is Jane Campion's first f...
# 64562  The Power of the Dog is Jane Campion's first f...
# 64563  The Power of the Dog is Jane Campion's first f...
# 64564  The Power of the Dog is Jane Campion's first f...
# 64565  The Power of the Dog is Jane Campion's first f...
#
#                                                RT_review sentiment_imdb  \
# 0      Martin Scorsese’s adaptation of the Hong Kong ...       Positive
# 1      If you like Scorsese, or if you just like thri...       Positive
# 2      Not only is The Departed not among the best of...       Positive
# 3      Nicholson is on good-to-great form as the pate...       Positive
# 4      One of the best crime dramas ever made, The De...       Positive
# ...                                                  ...            ...
# 64561  It's a slow build, and for most of the time, I...       Negative
# 64562  Campion handles such psychological denseness w...       Negative
# 64563  The Power of the Dog is a thought-provoking, d...       Negative
# 64564  When The Power of the Dog ends, there is an im...       Negative
# 64565  ‘The Power of the Dog’ is emotional and comple...       Negative
#
#       sentiment_rt Emotion_imdb    Emotion_RT
# 0         Positive     Fabulous  disappointed
# 1         Positive     Fabulous      Fabulous
# 2         Negative     Fabulous       Satisfy
# 3         Positive     Fabulous  disappointed
# 4         Positive     Fabulous      Fabulous
# ...            ...          ...           ...
# 64561     Positive      Satisfy      Fabulous
# 64562     Positive      Satisfy      Fabulous
# 64563     Positive      Satisfy      Fabulous
# 64564     Positive      Satisfy      Fabulous
# 64565     Negative      Satisfy       Satisfy
#
# [64566 rows x 10 columns]

# %%
data.sentiment_imdb.replace("Positive" , 10 , inplace = True)
data.sentiment_imdb.replace("Negative" , -10 , inplace = True)

data.sentiment_rt.replace("Positive" , 10 , inplace = True)
data.sentiment_rt.replace("Negative" , -10 , inplace = True)

data.Emotion_imdb.replace("Fabulous" , 10 , inplace = True)
data.Emotion_imdb.replace("disappointed" , -10 , inplace = True)
data.Emotion_imdb.replace("anger" , -8 , inplace = True)
data.Emotion_imdb.replace("surprise" , 7 , inplace = True)
data.Emotion_imdb.replace("fear" , -6 , inplace = True)
data.Emotion_imdb.replace("disgust" , -7 , inplace = True)
data.Emotion_imdb.replace("Satisfy" , 5 , inplace = True)

data.Emotion_RT.replace("Fabulous" , 10 , inplace = True)
data.Emotion_RT.replace("disappointed" , -10 , inplace = True)
data.Emotion_RT.replace("anger" , -8 , inplace = True)
data.Emotion_RT.replace("surprise" , 7 , inplace = True)
data.Emotion_RT.replace("fear" , -6 , inplace = True)
data.Emotion_RT.replace("disgust" , -7 , inplace = True)
data.Emotion_RT.replace("Satisfy" , 5 , inplace = True)
data.head(20)
# Out:
#            Title  Year  Rating                  Genres  \
# 0   The Departed  2006     8.5  Crime, Drama, Thriller
# 1   The Departed  2006     8.5  Crime, Drama, Thriller
# 2   The Departed  2006     8.5  Crime, Drama, Thriller
# 3   The Departed  2006     8.5  Crime, Drama, Thriller
# 4   The Departed  2006     8.5  Crime, Drama, Thriller
# 5   The Departed  2006     8.5  Crime, Drama, Thriller
# 6   The Departed  2006     8.5  Crime, Drama, Thriller
# 7   The Departed  2006     8.5  Crime, Drama, Thriller
# 8   The Departed  2006     8.5  Crime, Drama, Thriller
# 9   The Departed  2006     8.5  Crime, Drama, Thriller
# 10  The Departed  2006     8.5  Crime, Drama, Thriller
# 11  The Departed  2006     8.5  Crime, Drama, Thriller
# 12  The Departed  2006     8.5  Crime, Drama, Thriller
# 13  The Departed  2006     8.5  Crime, Drama, Thriller
# 14  The Departed  2006     8.5  Crime, Drama, Thriller
# 15  The Departed  2006     8.5  Crime, Drama, Thriller
# 16  The Departed  2006     8.5  Crime, Drama, Thriller
# 17  The Departed  2006     8.5  Crime, Drama, Thriller
# 18  The Departed  2006     8.5  Crime, Drama, Thriller
# 19  The Departed  2006     8.5  Crime, Drama, Thriller
#
#                                          User Reviews  \
# 0   When The Departed finally gained for Martin Sc...
# 1   When The Departed finally gained for Martin Sc...
# 2   When The Departed finally gained for Martin Sc...
# 3   When The Departed finally gained for Martin Sc...
# 4   When The Departed finally gained for Martin Sc...
# 5   When The Departed finally gained for Martin Sc...
# 6   When The Departed finally gained for Martin Sc...
# 7   When The Departed finally gained for Martin Sc...
# 8   When The Departed finally gained for Martin Sc...
# 9   When The Departed finally gained for Martin Sc...
# 10  When The Departed finally gained for Martin Sc...
# 11  When The Departed finally gained for Martin Sc...
# 12  When The Departed finally gained for Martin Sc...
# 13  When The Departed finally gained for Martin Sc...
# 14  When The Departed finally gained for Martin Sc...
# 15  When The Departed finally gained for Martin Sc...
# 16  When The Departed finally gained for Martin Sc...
# 17  When The Departed finally gained for Martin Sc...
# 18  Martin Scorsese returns to familiar territory ...
# 19  Martin Scorsese returns to familiar territory ...
#
#                                             RT_review  sentiment_imdb  \
# 0   Martin Scorsese’s adaptation of the Hong Kong ...              10
# 1   If you like Scorsese, or if you just like thri...              10
# 2   Not only is The Departed not among the best of...              10
# 3   Nicholson is on good-to-great form as the pate...              10
# 4   One of the best crime dramas ever made, The De...              10
# 5   [Scorsese] turns the clever cat-and-mouse stor...              10
# 6   Martin Scorsese’s adaptation of the Hong Kong ...              10
# 7   If you like Scorsese, or if you just like thri...              10
# 8   Not only is The Departed not among the best of...              10
# 9   Nicholson is on good-to-great form as the pate...              10
# 10  One of the best crime dramas ever made, The De...              10
# 11  [Scorsese] turns the clever cat-and-mouse stor...              10
# 12  Martin Scorsese’s adaptation of the Hong Kong ...              10
# 13  If you like Scorsese, or if you just like thri...              10
# 14  Not only is The Departed not among the best of...              10
# 15  Nicholson is on good-to-great form as the pate...              10
# 16  One of the best crime dramas ever made, The De...              10
# 17  [Scorsese] turns the clever cat-and-mouse stor...              10
# 18  Martin Scorsese’s adaptation of the Hong Kong ...              10
# 19  If you like Scorsese, or if you just like thri...              10
#
#     sentiment_rt  Emotion_imdb  Emotion_RT
# 0             10            10         -10
# 1             10            10          10
# 2            -10            10           5
# 3             10            10         -10
# 4             10            10          10
# 5             10            10         -10
# 6             10            10         -10
# 7             10            10          10
# 8            -10            10           5
# 9             10            10         -10
# 10            10            10          10
# 11            10            10         -10
# 12            10            10         -10
# 13            10            10          10
# 14           -10            10           5
# 15            10            10         -10
# 16            10            10          10
# 17            10            10         -10
# 18            10            10         -10
# 19            10            10          10

# %%
data.head(20)
# Out:
#            Title  Year  Rating                  Genres  \
# 0   The Departed  2006     8.5  Crime, Drama, Thriller
# 1   The Departed  2006     8.5  Crime, Drama, Thriller
# 2   The Departed  2006     8.5  Crime, Drama, Thriller
# 3   The Departed  2006     8.5  Crime, Drama, Thriller
# 4   The Departed  2006     8.5  Crime, Drama, Thriller
# 5   The Departed  2006     8.5  Crime, Drama, Thriller
# 6   The Departed  2006     8.5  Crime, Drama, Thriller
# 7   The Departed  2006     8.5  Crime, Drama, Thriller
# 8   The Departed  2006     8.5  Crime, Drama, Thriller
# 9   The Departed  2006     8.5  Crime, Drama, Thriller
# 10  The Departed  2006     8.5  Crime, Drama, Thriller
# 11  The Departed  2006     8.5  Crime, Drama, Thriller
# 12  The Departed  2006     8.5  Crime, Drama, Thriller
# 13  The Departed  2006     8.5  Crime, Drama, Thriller
# 14  The Departed  2006     8.5  Crime, Drama, Thriller
# 15  The Departed  2006     8.5  Crime, Drama, Thriller
# 16  The Departed  2006     8.5  Crime, Drama, Thriller
# 17  The Departed  2006     8.5  Crime, Drama, Thriller
# 18  The Departed  2006     8.5  Crime, Drama, Thriller
# 19  The Departed  2006     8.5  Crime, Drama, Thriller
#
#                                          User Reviews  \
# 0   When The Departed finally gained for Martin Sc...
# 1   When The Departed finally gained for Martin Sc...
# 2   When The Departed finally gained for Martin Sc...
# 3   When The Departed finally gained for Martin Sc...
# 4   When The Departed finally gained for Martin Sc...
# 5   When The Departed finally gained for Martin Sc...
# 6   When The Departed finally gained for Martin Sc...
# 7   When The Departed finally gained for Martin Sc...
# 8   When The Departed finally gained for Martin Sc...
# 9   When The Departed finally gained for Martin Sc...
# 10  When The Departed finally gained for Martin Sc...
# 11  When The Departed finally gained for Martin Sc...
# 12  When The Departed finally gained for Martin Sc...
# 13  When The Departed finally gained for Martin Sc...
# 14  When The Departed finally gained for Martin Sc...
# 15  When The Departed finally gained for Martin Sc...
# 16  When The Departed finally gained for Martin Sc...
# 17  When The Departed finally gained for Martin Sc...
# 18  Martin Scorsese returns to familiar territory ...
# 19  Martin Scorsese returns to familiar territory ...
#
#                                             RT_review  sentiment_imdb  \
# 0   Martin Scorsese’s adaptation of the Hong Kong ...              10
# 1   If you like Scorsese, or if you just like thri...              10
# 2   Not only is The Departed not among the best of...              10
# 3   Nicholson is on good-to-great form as the pate...              10
# 4   One of the best crime dramas ever made, The De...              10
# 5   [Scorsese] turns the clever cat-and-mouse stor...              10
# 6   Martin Scorsese’s adaptation of the Hong Kong ...              10
# 7   If you like Scorsese, or if you just like thri...              10
# 8   Not only is The Departed not among the best of...              10
# 9   Nicholson is on good-to-great form as the pate...              10
# 10  One of the best crime dramas ever made, The De...              10
# 11  [Scorsese] turns the clever cat-and-mouse stor...              10
# 12  Martin Scorsese’s adaptation of the Hong Kong ...              10
# 13  If you like Scorsese, or if you just like thri...              10
# 14  Not only is The Departed not among the best of...              10
# 15  Nicholson is on good-to-great form as the pate...              10
# 16  One of the best crime dramas ever made, The De...              10
# 17  [Scorsese] turns the clever cat-and-mouse stor...              10
# 18  Martin Scorsese’s adaptation of the Hong Kong ...              10
# 19  If you like Scorsese, or if you just like thri...              10
#
#     sentiment_rt  Emotion_imdb  Emotion_RT
# 0             10            10         -10
# 1             10            10          10
# 2            -10            10           5
# 3             10            10         -10
# 4             10            10          10
# 5             10            10         -10
# 6             10            10         -10
# 7             10            10          10
# 8            -10            10           5
# 9             10            10         -10
# 10            10            10          10
# 11            10            10         -10
# 12            10            10         -10
# 13            10            10          10
# 14           -10            10           5
# 15            10            10         -10
# 16            10            10          10
# 17            10            10         -10
# 18            10            10         -10
# 19            10            10          10

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

texts = data['sentiment_imdb'].astype(str).tolist()
labels = data['Emotion_imdb'].values

# Create a mapping from emotion labels to integers
label_to_int = {label: i for i, label in enumerate(set(labels))}

# Convert string labels to integers
labels = [label_to_int[label] for label in labels]

# Tokenize and create word index
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1

# Convert text to sequences of integers
sequences = tokenizer.texts_to_sequences(texts)

# Pad sequences to a fixed length
max_sequence_length = max(len(seq) for seq in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length, padding='post')

# Convert labels to categorical format
num_classes = len(set(labels))
labels_categorical = tf.keras.utils.to_categorical(labels, num_classes=num_classes)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels_categorical, test_size=0.2, random_state=42)

# Build the RNN model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=100, input_length=max_sequence_length))
model.add(LSTM(units=128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print model summary
print(model.summary())

# Train the model
batch_size = 32
epochs = 10
model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test loss: {loss}, Test accuracy: {accuracy}")
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_19 (Embedding)    (None, 1, 100)            200
#
#  lstm_2 (LSTM)               (None, 128)               117248
#
#  dense_18 (Dense)            (None, 3)                 387
#
# =================================================================
# Total params: 117,835
# Trainable params: 117,835
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 1453/1453 [==============================] - 19s 11ms/step - loss: 0.5690 - accuracy: 0.8195 - val_loss: 0.5471 - val_accuracy: 0.8266
# Epoch 2/10
# 1453/1453 [==============================] - 14s 9ms/step - loss: 0.5611 - accuracy: 0.8199 - val_loss: 0.5485 - val_accuracy: 0.8266
# Epoch 3/10
# 1453/1453 [==============================] - 15s 10ms/step - loss: 0.5606 - accuracy: 0.8199 - val_loss: 0.5507 - val_accuracy: 0.8266
# Epoch 4/10
# 1453/1453 [==============================] - 14s 9ms/step - loss: 0.5609 - accuracy: 0.8199 - val_loss: 0.5470 - val_accuracy: 0.8266
# Epoch 5/10
# 1453/1453 [==============================] - 13s 9ms/step - loss: 0.5604 - accuracy: 0.8199 - val_loss: 0.5461 - val_accuracy: 0.8266
# Epoch 6/10
# 1453/1453 [==============================] - 14s 9ms/step - loss: 0.5603 - accuracy: 0.8199 - val_loss: 0.5507 - val_accuracy: 0.8266
# Epoch 7/10
# 1453/1453 [==============================] - 14s 9ms/step - loss: 0.5602 - accuracy: 0.8199 - val_loss: 0.5463 - val_accuracy: 0.8266
# Epoch 8/10
# 1453/1453 [==============================] - 14s 10ms/step - loss: 0.5600 - accuracy: 0.8199 - val_loss: 0.5470 - val_accuracy: 0.8266
# Epoch 9/10
# 1453/1453 [==============================] - 14s 9ms/step - loss: 0.5599 - accuracy: 0.8199 - val_loss: 0.5463 - val_accuracy: 0.8266
# Epoch 10/10
# 1453/1453 [==============================] - 15s 10ms/step - loss: 0.5599 - accuracy: 0.8199 - val_loss: 0.5466 - val_accuracy: 0.8266
# 404/404 [==============================] - 1s 3ms/step - loss: 0.5375 - accuracy: 0.8289
# Test loss: 0.5375198721885681, Test accuracy: 0.8289453387260437

# %%
pip install tabulate
# Out:
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (0.9.0)

# %%
from tabulate import tabulate
# Make predictions on the test data
y_pred = model.predict(X_test)

# Convert predicted probabilities to class labels (0, 1, 2, etc.)
y_pred_labels = np.argmax(y_pred, axis=1)

# Convert one-hot encoded test labels back to integer labels
y_test_labels = np.argmax(y_test, axis=1)

# Calculate evaluation metrics
recall = recall_score(y_test_labels, y_pred_labels, average='macro')
precision = precision_score(y_test_labels, y_pred_labels, average='macro')
f1 = f1_score(y_test_labels, y_pred_labels, average='macro')
accuracy = accuracy_score(y_test_labels, y_pred_labels)

# Create the table with square boxes
table = [["Metric", "Value"],
         ["Recall", f"□ {recall:.4f}"],
         ["Precision", f"□ {precision:.4f}"],
         ["F1-score", f"□ {f1:.4f}"],
         ["Accuracy", f"□ {accuracy:.4f}"]]

# Print the table
print(tabulate(table, headers="firstrow", tablefmt="grid"))
# Out:
# 404/404 [==============================] - 1s 2ms/step
# +-----------+----------+
# | Metric    | Value    |
# +===========+==========+
# | Recall    | □ 0.3333 |
# +-----------+----------+
# | Precision | □ 0.2763 |
# +-----------+----------+
# | F1-score  | □ 0.3022 |
# +-----------+----------+
# | Accuracy  | □ 0.8289 |
# +-----------+----------+
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, GlobalMaxPooling1D, Dense, Dropout
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

texts = data['sentiment_imdb'].astype(str).tolist()
labels = data['Emotion_imdb'].values


# Create a mapping from emotion labels to integers
label_to_int = {label: i for i, label in enumerate(set(labels))}

# Convert string labels to integers
labels = [label_to_int[label] for label in labels]

# Tokenize and create word index
tokenizer = Tokenizer()
tokenizer.fit_on_texts(texts)
word_index = tokenizer.word_index
vocab_size = len(word_index) + 1

# Convert text to sequences of integers
sequences = tokenizer.texts_to_sequences(texts)

# Pad sequences to a fixed length
max_sequence_length = 100  # Set a reasonable sequence length based on your data
padded_sequences = pad_sequences(sequences, maxlen=max_sequence_length, padding='post')

# Convert labels to categorical format
num_classes = len(set(labels))
labels_categorical = tf.keras.utils.to_categorical(labels, num_classes=num_classes)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(padded_sequences, labels_categorical, test_size=0.2, random_state=42)

# Build the CNN model
model = Sequential()
model.add(Embedding(input_dim=vocab_size, output_dim=100, input_length=max_sequence_length))
model.add(Conv1D(filters=128, kernel_size=5, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Print model summary
print(model.summary())

# Train the model
batch_size = 32
epochs = 10
model.fit(X_train, y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)

# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test loss: {loss}, Test accuracy: {accuracy}")
# Out:
# Model: "sequential_18"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_18 (Embedding)    (None, 100, 100)          200
#
#  conv1d_16 (Conv1D)          (None, 96, 128)           64128
#
#  global_max_pooling1d_7 (Glo  (None, 128)              0
#  balMaxPooling1D)
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_17 (Dense)            (None, 3)                 195
#
# =================================================================
# Total params: 72,779
# Trainable params: 72,779
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/10
# 1453/1453 [==============================] - 66s 45ms/step - loss: 0.5705 - accuracy: 0.8194 - val_loss: 0.5464 - val_accuracy: 0.8266
# Epoch 2/10
# 1453/1453 [==============================] - 63s 44ms/step - loss: 0.5648 - accuracy: 0.8199 - val_loss: 0.5465 - val_accuracy: 0.8266
# Epoch 3/10
# 1453/1453 [==============================] - 64s 44ms/step - loss: 0.5634 - accuracy: 0.8199 - val_loss: 0.5470 - val_accuracy: 0.8266
# Epoch 4/10
# 1453/1453 [==============================] - 64s 44ms/step - loss: 0.5622 - accuracy: 0.8199 - val_loss: 0.5466 - val_accuracy: 0.8266
# Epoch 5/10
# 1453/1453 [==============================] - 65s 45ms/step - loss: 0.5620 - accuracy: 0.8199 - val_loss: 0.5467 - val_accuracy: 0.8266
# Epoch 6/10
# 1453/1453 [==============================] - 69s 47ms/step - loss: 0.5610 - accuracy: 0.8199 - val_loss: 0.5496 - val_accuracy: 0.8266
# Epoch 7/10
# 1453/1453 [==============================] - 65s 44ms/step - loss: 0.5616 - accuracy: 0.8199 - val_loss: 0.5486 - val_accuracy: 0.8266
# Epoch 8/10
# 1453/1453 [==============================] - 65s 45ms/step - loss: 0.5605 - accuracy: 0.8199 - val_loss: 0.5475 - val_accuracy: 0.8266
# Epoch 9/10
# 1453/1453 [==============================] - 64s 44ms/step - loss: 0.5605 - accuracy: 0.8199 - val_loss: 0.5466 - val_accuracy: 0.8266
# Epoch 10/10
# 1453/1453 [==============================] - 65s 45ms/step - loss: 0.5605 - accuracy: 0.8199 - val_loss: 0.5464 - val_accuracy: 0.8266
# 404/404 [==============================] - 6s 16ms/step - loss: 0.5375 - accuracy: 0.8289
# Test loss: 0.5375058650970459, Test accuracy: 0.8289453387260437

# %%
# Make predictions on the test data
y_pred = model.predict(X_test)

# Convert predicted probabilities to class labels (0, 1, 2, etc.)
y_pred_labels = np.argmax(y_pred, axis=1)

# Convert one-hot encoded test labels back to integer labels
y_test_labels = np.argmax(y_test, axis=1)

# Calculate evaluation metrics
recall = recall_score(y_test_labels, y_pred_labels, average='macro')
precision = precision_score(y_test_labels, y_pred_labels, average='macro')
f1 = f1_score(y_test_labels, y_pred_labels, average='macro')
accuracy = accuracy_score(y_test_labels, y_pred_labels)

# Create the table with square boxes
table = [["Metric", "Value"],
         ["Recall", f"□ {recall:.4f}"],
         ["Precision", f"□ {precision:.4f}"],
         ["F1-score", f"□ {f1:.4f}"],
         ["Accuracy", f"□ {accuracy:.4f}"]]

# Print the table
print(tabulate(table, headers="firstrow", tablefmt="grid"))
# Out:
# 404/404 [==============================] - 5s 12ms/step
# +-----------+----------+
# | Metric    | Value    |
# +===========+==========+
# | Recall    | □ 0.3333 |
# +-----------+----------+
# | Precision | □ 0.2763 |
# +-----------+----------+
# | F1-score  | □ 0.3022 |
# +-----------+----------+
# | Accuracy  | □ 0.8289 |
# +-----------+----------+
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
